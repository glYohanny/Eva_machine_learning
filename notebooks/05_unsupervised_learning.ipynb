# %% [markdown]
# # Análisis de Aprendizaje No Supervisado
#
# Este notebook presenta los resultados del análisis no supervisado:
# - Clustering (K-Means, DBSCAN, Hierarchical, GMM)
# - Reducción de Dimensionalidad (PCA, t-SNE, UMAP)
# - Detección de Anomalías (Isolation Forest, LOF)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pickle

# Configuración de visualización
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
# %matplotlib inline

# %% [markdown]
# ## 1. Cargar Resultados de Clustering

# %%
# Cargar métricas de clustering
with open('data/08_reporting/kmeans_metrics.json', 'r') as f:
    kmeans_metrics = json.load(f)

with open('data/08_reporting/dbscan_metrics.json', 'r') as f:
    dbscan_metrics = json.load(f)

with open('data/08_reporting/hierarchical_metrics.json', 'r') as f:
    hierarchical_metrics = json.load(f)

# Cargar comparación
clustering_comparison = pd.read_csv('data/08_reporting/clustering_comparison_table.csv')

print("Comparación de Algoritmos de Clustering:")
print(clustering_comparison.to_string(index=False))
